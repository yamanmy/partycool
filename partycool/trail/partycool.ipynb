# %% [markdown]
# # Import modules

# %%
# Data manipulation and plotting
import os
import math
import time
import numpy as np
from collections import OrderedDict
from sklearn.cluster import MeanShift, estimate_bandwidth, KMeans
from sklearn.preprocessing import StandardScaler
from scipy import ndimage, spatial
import imageio
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from scipy.ndimage import gaussian_filter
from skimage import data
from skimage import img_as_float
from skimage.morphology import reconstruction
#import cv2 #use this if you did not uploaded before: pip install opencv-python

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
def img_reader(img_path):
    '''
    The function returns a 2D array for the loaded img, and also gives a preview for the img
    img_path: input path for the img location
    '''
    #Read the array
    img_array = mpimg.imread(img_path)
    
    #Preview
    plt.figure(figsize=(15,15))
    imgplot = plt.imshow(img_array,cmap=plt.cm.gray)
    plt.axis('off')
    plt.show()
    
    return img_array

# %%
sem_array = img_reader('example_images/sem_1.jpg')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage as ndi

from skimage import feature

im = sem_array


# Compute the Canny filter for two values of sigma
edges = feature.canny(im, sigma=2)

# display results
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20, 10),
                                    sharex=True, sharey=True)

ax1.imshow(im, cmap=plt.cm.gray)
ax1.axis('off')
ax1.set_title('noisy image', fontsize=20)


ax2.imshow(edges, cmap=plt.cm.gray)
ax2.axis('off')
ax2.set_title(r'Canny filter, $\sigma=2$', fontsize=20)

fig.tight_layout()

plt.show()
