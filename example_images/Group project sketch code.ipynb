# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img=mpimg.imread('My040-s1-5xCPFtristirs-2Aumy5s1_T1_008.tif')

# %%
img_tiff=mpimg.imread('My040-s1-5xCPFtristirs-2Aumy5s1_T1_008.tif')

# %%
plt.figure(figsize=(10,10))
imgplot = plt.imshow(img_tiff)
plt.axis('off')
# Out:
# (-0.5, 3071.5, 2187.5, -0.5)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage as ndi

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-36dba2c2951f> in <module>
#       1 from skimage.data import camera
# ----> 2 from skimage.filters import roberts, sobel, sobel_h, sobel_v, scharr, \
#       3     scharr_h, scharr_v, prewitt, prewitt_v, prewitt_h, farid_v, farid_h
#       4
#       5 image = camera()
#
# ImportError: cannot import name 'farid_v' from 'skimage.filters' (//anaconda3/lib/python3.7/site-packages/skimage/filters/__init__.py)

# %%
img

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage as ndi

from skimage import feature


# Generate noisy image of a square
im = np.zeros((128, 128))
im[32:-32, 32:-32] = 1

im = ndi.rotate(im, 15, mode='constant')
im = ndi.gaussian_filter(im, 4)
im += 0.2 * np.random.random(im.shape)

# Compute the Canny filter for two values of sigma
edges1 = feature.canny(im)
edges2 = feature.canny(im, sigma=3)

# display results
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(8, 3),
                                    sharex=True, sharey=True)

ax1.imshow(im, cmap=plt.cm.gray)
ax1.axis('off')
ax1.set_title('noisy image', fontsize=20)

ax2.imshow(edges1, cmap=plt.cm.gray)
ax2.axis('off')
ax2.set_title(r'Canny filter, $\sigma=1$', fontsize=20)

ax3.imshow(edges2, cmap=plt.cm.gray)
ax3.axis('off')
ax3.set_title(r'Canny filter, $\sigma=3$', fontsize=20)

fig.tight_layout()

plt.show()

# %%
img_edges1 = feature.canny(img_tiff)
img_edges2 = feature.canny(img_tiff, sigma=3)

fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(8, 3),
                                    sharex=True, sharey=True)

ax1.imshow(img_tiff, cmap=plt.cm.gray)
ax1.axis('off')
ax1.set_title('noisy image', fontsize=20)

ax2.imshow(img_edges1, cmap=plt.cm.gray)
ax2.axis('off')
ax2.set_title(r'Canny filter, $\sigma=1$', fontsize=20)

ax3.imshow(img_edges2, cmap=plt.cm.gray)
ax3.axis('off')
ax3.set_title(r'Canny filter, $\sigma=3$', fontsize=20)

fig.tight_layout()

plt.show()
